# %%
# Load and view the data
import pandas as pd
df=pd.read_csv(r'C:\Users\Vivek\Desktop\Projects\Crime Hostpot Analysis using Clustering\Indian Maharashta District Wise Crime Dataset.csv')
df.head(df.shape[0])
# Out:
#        District  Sum of RAPE  Sum of OTHER IPC CRIMES  \
# 0    AHMEDNAGAR          653                    16686
# 1         AKOLA          299                    14930
# 2      AMRAVATI          878                    21795
# 3    AURANGABAD          415                    15863
# 4          BEED          322                     9117
# 5      BHANDARA          338                     9711
# 6      BULDHANA          381                    12853
# 7    CHANDRAPUR          469                    13706
# 8         DHULE          178                     8667
# 9    GADCHIROLI          245                     4326
# 10       GONDIA          348                     7097
# 11      HINGOLI          175                     5493
# 12      JALGAON          485                    15214
# 13        JALNA          193                     7829
# 14     KOLHAPUR          348                    11557
# 15        LATUR          231                    11722
# ...

# %%
# See summary statistic of all features
df.describe()
# Out:
#        Sum of RAPE  Sum of OTHER IPC CRIMES  \
# count    35.000000                35.000000
# mean    513.885714             16001.714286
# std     453.629596             15592.319713
# min      98.000000              2661.000000
# 25%     242.500000              7524.500000
# 50%     348.000000             11722.000000
# 75%     558.000000             17463.500000
# max    2193.000000             80304.000000
#
#        Sum of CAUSING DEATH BY NEGLIGENCE  \
# count                           35.000000
# mean                          3846.085714
# std                           3364.587532
# min                            880.000000
# 25%                           1580.000000
# 50%                           2737.000000
# 75%                           4420.500000
# max                          16594.000000
#
#        Sum of IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  \
# count                                          35.000000
# ...

# %%
# df = df.drop(['State'], axis = 1)
# dfc = dfc.drop(['Grand Total','Lat-Long', 'X', 'Y'], axis = 1)
df.columns
# Out:
# Index(['District', 'Sum of RAPE', 'Sum of OTHER IPC CRIMES',
#        'Sum of CAUSING DEATH BY NEGLIGENCE',
#        'Sum of IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES',
#        'Sum of DOWRY DEATHS', 'Sum of HURT/GREVIOUS HURT',
#        'Sum of CRUELTY BY HUSBAND OR HIS RELATIVES',
#        'Sum of ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
#        'Sum of INSULT TO MODESTY OF WOMEN', 'Sum of ARSON',
#        'Sum of COUNTERFIETING', 'Sum of CHEATING',
#        'Sum of CRIMINAL BREACH OF TRUST', 'Sum of RIOTS', 'Sum of AUTO THEFT',
#        'Sum of OTHER THEFT', 'Sum of BURGLARY',
#        'Sum of KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS', 'Sum of THEFT',
#        'Sum of ROBBERY', 'Sum of PREPARATION AND ASSEMBLY FOR DACOITY',
#        'Sum of KIDNAPPING & ABDUCTION',
#        'Sum of KIDNAPPING AND ABDUCTION OF OTHERS', 'Sum of DACOITY',
#        'Sum of CUSTODIAL RAPE', 'Sum of MURDER',
# ...

# %% [markdown]
# We can see that we have data for 36 States and Union Territories of India. The range of mean_dropout feature is from 3.7-19.5 whereas others are above 40-100( enrollment_ratio even crosses 100). Also the mean values of some of them significantly differs from others. This different range of data among features may bias the result in case of clustering algorithms where we will use Euclidean Distance to calculate distance between points. So we will first normalize them all between 0 and 1 using MinMaxScaling().

# %%
df.rename(columns = {'Sum of RAPE':'RAPE',
                     'Sum of OTHER IPC CRIMES':'OTHER IPC CRIMES',
       'Sum of CAUSING DEATH BY NEGLIGENCE':'CAUSING DEATH BY NEGLIGENCE',
       'Sum of IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES':'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES',
       'Sum of DOWRY DEATHS':'DOWRY DEATHS', 
       'Sum of HURT/GREVIOUS HURT':'HURT/GREVIOUS HURT',
       'Sum of CRUELTY BY HUSBAND OR HIS RELATIVES':'CRUELTY BY HUSBAND OR HIS RELATIVES',
       'Sum of ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY':'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
       'Sum of INSULT TO MODESTY OF WOMEN':'INSULT TO MODESTY OF WOMEN',
       'Sum of ARSON':'ARSON',
       'Sum of COUNTERFIETING':'COUNTERFIETING', 
       'Sum of CHEATING':'CHEATING',
       'Sum of CRIMINAL BREACH OF TRUST':'CRIMINAL BREACH OF TRUST', 
       'Sum of RIOTS':'RIOTS', 
       'Sum of AUTO THEFT':'AUTO THEFT',
       'Sum of OTHER THEFT':'OTHER THEFT', 
       'Sum of BURGLARY':'BURGLARY',
       'Sum of KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS':'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS', 
       'Sum of THEFT':'THEFT',
       'Sum of ROBBERY':'ROBBERY', 
       'Sum of PREPARATION AND ASSEMBLY FOR DACOITY':'PREPARATION AND ASSEMBLY FOR DACOITY',
       'Sum of KIDNAPPING & ABDUCTION':'KIDNAPPING & ABDUCTION',
       'Sum of KIDNAPPING AND ABDUCTION OF OTHERS':'KIDNAPPING AND ABDUCTION OF OTHERS', 
       'Sum of DACOITY':'DACOITY',
       'Sum of CUSTODIAL RAPE':'CUSTODIAL RAPE', 
       'Sum of MURDER':'MURDER',
       'Sum of CULPABLE HOMICIDE NOT AMOUNTING TO MURDER':'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 
       'Sum of OTHER RAPE':'OTHER RAPE',
       'Sum of ATTEMPT TO MURDER':'ATTEMPT TO MURDER'}, inplace = True)

# %%
df.columns
# Out:
# Index(['District', 'RAPE', 'OTHER IPC CRIMES', 'CAUSING DEATH BY NEGLIGENCE',
#        'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES', 'DOWRY DEATHS',
#        'HURT/GREVIOUS HURT', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
#        'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
#        'INSULT TO MODESTY OF WOMEN', 'ARSON', 'COUNTERFIETING', 'CHEATING',
#        'CRIMINAL BREACH OF TRUST', 'RIOTS', 'AUTO THEFT', 'OTHER THEFT',
#        'BURGLARY', 'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS', 'THEFT',
#        'ROBBERY', 'PREPARATION AND ASSEMBLY FOR DACOITY',
#        'KIDNAPPING & ABDUCTION', 'KIDNAPPING AND ABDUCTION OF OTHERS',
#        'DACOITY', 'CUSTODIAL RAPE', 'MURDER',
#        'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'OTHER RAPE',
#        'ATTEMPT TO MURDER', 'Grand Total', 'Lat', 'Long', 'Lat-Long'],
#       dtype='object')

# %%
dfc=df.copy()

# %%
df = df.drop(['Grand Total', 'Lat', 'Long', 'Lat-Long'], axis = 1)

# %%
# Normalization of features
from sklearn.preprocessing import MinMaxScaler
mx = MinMaxScaler()
df[['RAPE', 'OTHER IPC CRIMES', 'CAUSING DEATH BY NEGLIGENCE',
       'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES', 'DOWRY DEATHS',
       'HURT/GREVIOUS HURT', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
       'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
       'INSULT TO MODESTY OF WOMEN', 'ARSON', 'COUNTERFIETING', 'CHEATING',
       'CRIMINAL BREACH OF TRUST', 'RIOTS', 'AUTO THEFT', 'OTHER THEFT',
       'BURGLARY', 'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS', 'THEFT',
       'ROBBERY', 'PREPARATION AND ASSEMBLY FOR DACOITY',
       'KIDNAPPING & ABDUCTION', 'KIDNAPPING AND ABDUCTION OF OTHERS',
       'DACOITY', 'CUSTODIAL RAPE', 'MURDER',
       'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'OTHER RAPE',
       'ATTEMPT TO MURDER']] = pd.DataFrame(mx.fit_transform(df.drop('District',axis=1)))

# %%
df.head()
# Out:
#      District      RAPE  OTHER IPC CRIMES  CAUSING DEATH BY NEGLIGENCE  \
# 0  AHMEDNAGAR  0.264916          0.180634                     0.380425
# 1       AKOLA  0.095943          0.158018                     0.040346
# 2    AMRAVATI  0.372315          0.246436                     0.124348
# 3  AURANGABAD  0.151313          0.170035                     0.234441
# 4        BEED  0.106921          0.083150                     0.130648
#
#    IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  DOWRY DEATHS  \
# 0                                          0.0      0.212987
# 1                                          0.0      0.168831
# 2                                          0.0      0.233766
# 3                                          0.0      1.000000
# 4                                          0.0      0.267532
#
#    HURT/GREVIOUS HURT  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 0            0.149240                             1.000000
# ...

# %% [markdown]
# We don't know the number of clusters beforehand. We will determine it in case of KMeans Clustering algorithm using Elbow Method. This is called Elbow Method because we will choose the cluster at that point of the graph from where it stops falling sleeply(just like an elbow of hand). It is the point where the WCSS(Within Cluster Sum of Squares) decreases very slowly.
#
# WCSS is the distance between points in a cluster.

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
wcss=[]
for i in range(1,10):
  kmeans=KMeans(i,random_state=3)
  kmeans.fit(df.drop('District',axis=1))
  wcss.append(kmeans.inertia_)
plt.plot(range(1,10),wcss,'-o')
plt.xlabel('No. of clusters')
plt.ylabel('WCSS')
print(wcss)
plt.show()
# Out:
# [49.9894533074729, 20.883484374877327, 15.87023244131047, 11.338106255613031, 9.219592517657652, 7.715762180297226, 6.434349434770619, 5.306251902089446, 4.482348608551696]

# %% [markdown]
# From WCSS values and the Scree Plot we can see that 2 or 3 can be the ideal number of clusters.
#
# We will use some metric to choose the ideal number of clusters between 2 and 3

# %% [markdown]
# We can use suitable metrics to decide exact number of cluster between 2 and 3. The metrics we will use are:
#
# 1. Silhoutte Score- It ranges from -1 to 1. Higher the value better our clusters are. Closer to 1 means perfect clusters. 0 mean the point lies at the border of it's cluster. Negative value means that the point is classified into wrong cluster.
#
# 2. Calinski-Harabasz Index denotes how the data points are spread within a cluster. Higher the score, denser is the cluster thus the cluster is better. It starts from 0 and have no upper limit.
#
# 3. Davies Boulden Index measures the average similarity between cluster using the ratio of the distance between a cluster and it's closest point & the average distance between each data point of a cluster and it's cluster center.Closer the score is to 0, better our clusters are as it indicates clusters are well separated.

# %%
from sklearn.metrics import silhouette_score,calinski_harabasz_score,davies_bouldin_score

# %%
# Though we saw that the ideal number of cluster would be either 2 or 3 we try here with 2,3,4,5 just for the sake of demonstration.
l1 = []
l2 = []
l3 = []
l4 = []

for i in (2,3,4,5):
  kmean = KMeans(i,random_state=42)
  mod_k = kmean.fit(df.drop('District',axis=1))
  pred_k1 = mod_k.predict(df.drop('District',axis=1))
  kmean_sil = silhouette_score(df.drop('District',axis=1),pred_k1,metric='euclidean')
  kmean_cal = calinski_harabasz_score(df.drop('District',axis=1),pred_k1)
  kmean_dav = davies_bouldin_score(df.drop('District',axis=1),pred_k1)
  print(i,'\t','Silhouette Score:' ,kmean_sil,',Calinski Harbasz Score: ',kmean_cal,',Davies Bouldin Score: ',kmean_dav)
  l1.append(kmean_sil)
  l2.append(kmean_cal)
  l3.append(kmean_dav)
  l4.append(i)
# Out:
# 2 	 Silhouette Score: 0.6610419095122377 ,Calinski Harbasz Score:  45.993137808512685 ,Davies Bouldin Score:  0.6784841348987949
# 3 	 Silhouette Score: 0.3204314747223733 ,Calinski Harbasz Score:  34.5257389958768 ,Davies Bouldin Score:  1.061828235118554
# 4 	 Silhouette Score: 0.31800667371413033 ,Calinski Harbasz Score:  35.226098950298116 ,Davies Bouldin Score:  0.8835239985460351
# 5 	 Silhouette Score: 0.3137920642798253 ,Calinski Harbasz Score:  33.165669235162675 ,Davies Bouldin Score:  0.7370509903808904

# %%
pd.DataFrame({'Cluster_number':l4,'Silhoutte Score':l1,'Calinski Harabasz Index':l2,'Davies Bouldin Score':l3})
# Out:
#    Cluster_number  Silhoutte Score  Calinski Harabasz Index  \
# 0               2         0.661042                45.993138
# 1               3         0.320431                34.525739
# 2               4         0.318007                35.226099
# 3               5         0.313792                33.165669
#
#    Davies Bouldin Score
# 0              0.678484
# 1              1.061828
# 2              0.883524
# 3              0.737051

# %% [markdown]
# As expected from screeplot, 3 has best SilHouette Score and Davies Bouldin Score and second best Calinski Harabasz Score. So 3 number of clusters can be an ideal choice.

# %%
# Let's try performing KMeans Clustering on unnormalized data and check what's happening
l1 = []
l2 = []
l3 = []
l4 = []
for i in (2,3,4,5):
  kmean = KMeans(i,random_state=42)
  mod_k = kmean.fit(dfc.drop(['District','Grand Total', 'Lat', 'Long', 'Lat-Long'], axis=1))
  pred_k2 = mod_k.predict(dfc.drop(['District','Grand Total', 'Lat', 'Long', 'Lat-Long'],axis=1))
  kmean_sil = silhouette_score(dfc.drop(['District','Grand Total', 'Lat', 'Long', 'Lat-Long'],axis=1),pred_k2,metric='euclidean')
  kmean_cal = calinski_harabasz_score(dfc.drop(['District','Grand Total', 'Lat', 'Long', 'Lat-Long'],axis=1),pred_k2)
  kmean_dav = davies_bouldin_score(dfc.drop(['District','Grand Total', 'Lat', 'Long', 'Lat-Long'],axis=1),pred_k2)
  print(i,'\t','Silhouette Score:' ,kmean_sil,',Calinski Harbasz Score: ',kmean_cal,',Davies Bouldin Score: ',kmean_dav)
  l1.append(kmean_sil)
  l2.append(kmean_cal)
  l3.append(kmean_dav)
  l4.append(i)
# Out:
# 2 	 Silhouette Score: 0.8596140482019012 ,Calinski Harbasz Score:  83.3953251137972 ,Davies Bouldin Score:  0.07295435726648047
# 3 	 Silhouette Score: 0.7565378602833791 ,Calinski Harbasz Score:  198.2832038209427 ,Davies Bouldin Score:  0.34074984295836125
# 4 	 Silhouette Score: 0.422909249128084 ,Calinski Harbasz Score:  213.46104391738587 ,Davies Bouldin Score:  0.5594286602465
# 5 	 Silhouette Score: 0.4035822936657211 ,Calinski Harbasz Score:  232.74186223295357 ,Davies Bouldin Score:  0.5139831421283707

# %%
pd.DataFrame({'Cluster_number':l4,'Silhoutte Score':l1,'Calinski Harabasz Index':l2,'Davies Bouldin Score':l3})
# Out:
#    Cluster_number  Silhoutte Score  Calinski Harabasz Index  \
# 0               2         0.859614                83.395325
# 1               3         0.756538               198.283204
# 2               4         0.422909               213.461044
# 3               5         0.403582               232.741862
#
#    Davies Bouldin Score
# 0              0.072954
# 1              0.340750
# 2              0.559429
# 3              0.513983

# %% [markdown]
# We can see that best cluster no. in this case is 3. But both the Silhoutte Score and Davies Bouldin Score detoriated though Calinski Harabarz score improved a bit. Overall, the model performance detoriated a bit. So as mentioned before, normalizing data points before clustering do give good results.

# %% [markdown]
# Next we will use a Hierarchical Clustering technique called Agglomerative Clustering. It is a bottom-up clustering approach where each data point is first considered as individual cluster and then merge closest points according to a distance metric until a single cluster is obtained.
#
# The Heirarchical Clustering can be visualized using a dendrogram as shown below. The suitable number of clusters for this data is shown as 3 in the dendrogram.

# %%
from scipy.cluster.hierarchy import dendrogram
import scipy.cluster.hierarchy as sch
dendrogram=sch.dendrogram(sch.linkage(df.drop('District',axis=1),method='ward'))

# %% [markdown]
# From the dendrogram we saw that the ideal number of clusters for the dataset is 3, the kmeans algorithm also found the same. We will again use Silhoutte Score, Calinski Harabarz Index and Davis Bouldin Score to validate this.

# %%
list1=['single','complete','average','ward']

# %%
from sklearn.cluster import AgglomerativeClustering
l1=[]
l2=[]
l3=[]
l4=[]
l5=[]
for j in list1:
  for i in (2,3,4,5):
    agg_m=AgglomerativeClustering(n_clusters=i,affinity='euclidean',linkage=j)
    mod_k=agg_m.fit(df.drop('District',axis=1))
    #pred_k=mod_k.predict(df.drop('District',axis=1))
    kmean_sil=silhouette_score(df.drop('District',axis=1),agg_m.labels_,metric='euclidean')
    kmean_cal=calinski_harabasz_score(df.drop('District',axis=1),agg_m.labels_)
    kmean_dav=davies_bouldin_score(df.drop('District',axis=1),agg_m.labels_)
    print(i,j)
    print(i,'\t','Silhouette Score:' ,kmean_sil,',Calinski Harbasz Score: ',kmean_cal,',Davies Bouldin Score: ',kmean_dav)
    print('---------')
    print('\n')
    l1.append(i)
    l2.append(j)
    l3.append(kmean_sil)
    l4.append(kmean_cal)
    l5.append(kmean_dav)
# Out:
# 2 single
# 2 	 Silhouette Score: 0.6635575284546162 ,Calinski Harbasz Score:  14.963554122662071 ,Davies Bouldin Score:  0.20845640483156602
# ---------
#
#
# 3 single
# 3 	 Silhouette Score: 0.6205049163393358 ,Calinski Harbasz Score:  17.55155193861771 ,Davies Bouldin Score:  0.2102701018497782
# ---------
#
#
# 4 single
# 4 	 Silhouette Score: 0.5638063502384927 ,Calinski Harbasz Score:  25.85816166078334 ,Davies Bouldin Score:  0.43069578723458046
# ---------
#
#
# 5 single
# 5 	 Silhouette Score: 0.5012374605307763 ,Calinski Harbasz Score:  20.377233863687454 ,Davies Bouldin Score:  0.23444755258581065
# ---------
#
#
# 2 complete
# 2 	 Silhouette Score: 0.6610419095122377 ,Calinski Harbasz Score:  45.993137808512685 ,Davies Bouldin Score:  0.6784841348987949
# ---------
#
#
# 3 complete
# 3 	 Silhouette Score: 0.6172599797480485 ,Calinski Harbasz Score:  32.79573764955942 ,Davies Bouldin Score:  0.5462584009123033
# ---------
#
#
# 4 complete
# ...

# %%
pd.DataFrame({'Cluster':l1,'Linkage':l2,'Silhoutte Score':l3,'Calinski Harabasz Index':l4,'Davies Bouldin Score':l5})
# Out:
#     Cluster   Linkage  Silhoutte Score  Calinski Harabasz Index  \
# 0         2    single         0.663558                14.963554
# 1         3    single         0.620505                17.551552
# 2         4    single         0.563806                25.858162
# 3         5    single         0.501237                20.377234
# 4         2  complete         0.661042                45.993138
# 5         3  complete         0.617260                32.795738
# 6         4  complete         0.563806                25.858162
# 7         5  complete         0.261459                30.903218
# 8         2   average         0.661042                45.993138
# 9         3   average         0.617260                32.795738
# 10        4   average         0.563806                25.858162
# 11        5   average         0.501237                20.377234
# 12        2      ward         0.661042                45.993138
# 13        3      ward         0.269788                32.849642
# ...

# %% [markdown]
# As observed from the output, ideal number of clusters is indeed 3 with linkage method '**average**'.

# %%
l1=[]
l2=[]
l3=[]
l4=[]
l5=[]
for j in list1:
 for i in (2,3,4,5):
  agm=AgglomerativeClustering(n_clusters=i,affinity='euclidean',linkage=j)
  mod_k=agm.fit(dfc.drop(['District','Grand Total', 'Lat', 'Long', 'Lat-Long'],axis=1))
  #pred_k=mod_k.predict(df.drop('Neighbourhood',axis=1))
  kmean_sil=silhouette_score(dfc.drop(['District','Grand Total', 'Lat', 'Long', 'Lat-Long'],axis=1),agm.labels_,metric='euclidean')
  kmean_cal=calinski_harabasz_score(dfc.drop(['District','Grand Total', 'Lat', 'Long', 'Lat-Long'],axis=1),agm.labels_)
  kmean_dav=davies_bouldin_score(dfc.drop(['District','Grand Total', 'Lat', 'Long', 'Lat-Long'],axis=1),agm.labels_)
  print(i,j)
  print(i,'\t','Silhouette Score:' ,kmean_sil,',Calinski Harbasz Score: ',kmean_cal,',Davies Bouldin Score: ',kmean_dav)
  print('---------')
  print('\n')
  l1.append(i)
  l2.append(j)
  l3.append(kmean_sil)
  l4.append(kmean_cal)
  l5.append(kmean_dav)
# Out:
# 2 single
# 2 	 Silhouette Score: 0.8596140482019012 ,Calinski Harbasz Score:  83.3953251137972 ,Davies Bouldin Score:  0.07295435726648047
# ---------
#
#
# 3 single
# 3 	 Silhouette Score: 0.7551771978202417 ,Calinski Harbasz Score:  144.51545152939082 ,Davies Bouldin Score:  0.25977615391826014
# ---------
#
#
# 4 single
# 4 	 Silhouette Score: 0.6972156448658879 ,Calinski Harbasz Score:  102.27751437576693 ,Davies Bouldin Score:  0.11648539229194135
# ---------
#
#
# 5 single
# 5 	 Silhouette Score: 0.6480456885948334 ,Calinski Harbasz Score:  137.30077227528352 ,Davies Bouldin Score:  0.12439170616412984
# ---------
#
#
# 2 complete
# 2 	 Silhouette Score: 0.8596140482019012 ,Calinski Harbasz Score:  83.3953251137972 ,Davies Bouldin Score:  0.07295435726648047
# ---------
#
#
# 3 complete
# 3 	 Silhouette Score: 0.7565378602833791 ,Calinski Harbasz Score:  198.2832038209427 ,Davies Bouldin Score:  0.34074984295836125
# ---------
#
#
# 4 complete
# ...

# %%
pd.DataFrame({'Cluster':l1,'Linkage':l2,'Silhoutte Score':l3,'Calinski Harabasz Index':l4,'Davies Bouldin Score':l5})
# Out:
#     Cluster   Linkage  Silhoutte Score  Calinski Harabasz Index  \
# 0         2    single         0.859614                83.395325
# 1         3    single         0.755177               144.515452
# 2         4    single         0.697216               102.277514
# 3         5    single         0.648046               137.300772
# 4         2  complete         0.859614                83.395325
# 5         3  complete         0.756538               198.283204
# 6         4  complete         0.659896               162.717389
# 7         5  complete         0.403415               231.958881
# 8         2   average         0.859614                83.395325
# 9         3   average         0.756538               198.283204
# 10        4   average         0.659896               162.717389
# 11        5   average         0.648046               137.300772
# 12        2      ward         0.859614                83.395325
# 13        3      ward         0.756538               198.283204
# ...

# %% [markdown]
# In case of unnormalized dataset, 3 clusters with complete linkage is the best. But in case of normalized dataset, the performance is better. There the Silhoutte Score and Calinski Harabarz Score performance is better though the Davies Bouldin score pervermance is a bit lower.

# %% [markdown]
# Cluster 3 for both algorithms KMeans and Agglomerative have same performance. Let's see the how the values for each feature vary across the two clusters.

# %%
kmeansf = KMeans(n_clusters = 2,random_state = 31)
kmeansf.fit(df.drop(['District'],axis = 1))
pred_kk = kmeansf.predict(df.drop(['District'],axis=1))
df['pred_k2'] = pred_kk

# %%
df.head()
# Out:
#      District      RAPE  OTHER IPC CRIMES  CAUSING DEATH BY NEGLIGENCE  \
# 0  AHMEDNAGAR  0.264916          0.180634                     0.380425
# 1       AKOLA  0.095943          0.158018                     0.040346
# 2    AMRAVATI  0.372315          0.246436                     0.124348
# 3  AURANGABAD  0.151313          0.170035                     0.234441
# 4        BEED  0.106921          0.083150                     0.130648
#
#    IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  DOWRY DEATHS  \
# 0                                          0.0      0.212987
# 1                                          0.0      0.168831
# 2                                          0.0      0.233766
# 3                                          0.0      1.000000
# 4                                          0.0      0.267532
#
#    HURT/GREVIOUS HURT  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 0            0.149240                             1.000000
# ...

# %%
df1 = pd.melt(frame=df.drop('District',axis=1),id_vars='pred_k2',var_name='parameters',value_name='values')
df1.head()
# Out:
#    pred_k2 parameters    values
# 0        0       RAPE  0.264916
# 1        0       RAPE  0.095943
# 2        0       RAPE  0.372315
# 3        0       RAPE  0.151313
# 4        0       RAPE  0.106921

# %%
import seaborn as sns 
sns.factorplot(data=df1, y = 'values', x = 'pred_k2',col = 'parameters', kind = 'box',sharey = False)
# Out:
# C:\Users\Vivek\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
agg_mod_ = AgglomerativeClustering(n_clusters = 2, affinity = 'euclidean', linkage = 'ward')
agg_mod_.fit(df.drop('District', axis=1))
df['agg_clust2']=agg_mod_.labels_

# %%
df2=pd.melt(frame=df.drop(['District','pred_k2'],axis=1),id_vars='agg_clust2',var_name='parameters',value_name='values')
df2.head()
# Out:
#    agg_clust2 parameters    values
# 0           0       RAPE  0.264916
# 1           0       RAPE  0.095943
# 2           0       RAPE  0.372315
# 3           0       RAPE  0.151313
# 4           0       RAPE  0.106921

# %%
sns.factorplot(data=df2,y='values',x='agg_clust2',col='parameters',kind='box',sharey=False)
# Out:
# C:\Users\Vivek\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# We see that both the KMeans and Agglomerative Clustering have the value range of each of the feature/category exactly the same.
#
# Based on careful observations of the boxplots we can conclude that category has higher values of for comp, electricity, water and the toilets features. So we can says the states falling in category 0 has much better infrastructure than schools of category 1. On the otherhand, the dropout rate is almost same for both groups with 0 has higher variablity. While the enrollment ratio is good for group 1.
#
# So we can call group 0 as Higher Infrastructure, Lesser Enrollment-Ratio and and group 1 as Less-Infrastructure, Better Enrollment-Ratio.

# %%
# !pip install fuzzy-c-means

# %%
# %matplotlib inline
# import numpy as np
# from fcmeans import FCM
# from matplotlib import pyplot as plt

# %%
# df.head()

# %%
# X = df.iloc[:,1:30].values

# n_clusters_list = [2, 3, 4, 5, 6, 7]
# models = list()
# for n_clusters in n_clusters_list:
#     fcm = FCM(n_clusters)
#     abc = fcm.fit(X)
#     models.append(fcm)

# %%
# # num_clusters = len(n_clusters_list)
# # f, axes = plt.subplots(3, 2, figsize=(11,16))
# # for n_clusters, model, axe in zip(n_clusters_list, models, axes.ravel()):
# #     # get validation metrics
# #     pc = model.partition_coefficient
# #     pec = model.partition_entropy_coefficient
    
# #     fcm_centers = model.centers
# #     fcm_labels = model.predict(X)
# #     # plot result
# #     axe.scatter(X[:,0], X[:,1], c=fcm_labels, alpha=.1)
# #     axe.scatter(fcm_centers[:,0], fcm_centers[:,1], marker="+", s=500, c='black')
# #     axe.set_title(f'n_clusters = {n_clusters}, PC = {pc:.3f}, PEC = {pec:.3f}')
# # plt.show()


# FPC = []
# FPEC = []
# for model in models:
#   FPC.append(model.partition_coefficient)
#   FPEC.append(model.partition_entropy_coefficient)

# fig2, ax2 = plt.subplots(1, 2, figsize = (16,8))
# ax2[0].plot(n_clusters_list, FPC)
# ax2[1].plot(n_clusters_list, FPEC)
# ax2[0].set_xlabel("Number of centers")
# ax2[0].set_ylabel("Fuzzy partition coefficient")
# ax2[1].set_xlabel("Number of centers")
# ax2[1].set_ylabel("Fuzzy partition coefficient")

# %%
# # Though we saw that the ideal number of cluster would be 3, we try here with 3,4,5 just for the sake of demonstration.
# l1 = []
# l2 = []
# l3 = []
# l4 = []
# X = df.iloc[:,1:30].values

# for i in (2,3,4,5):
#   fcm = FCM(i)
#   mod_k = fcm.fit(X)
#   fcm_k1 = fcm.predict(X)
#   fcm_sil = silhouette_score(X,fcm_k1,metric='euclidean')
#   fcm_cal = calinski_harabasz_score(X,fcm_k1)
#   fcm_dav = davies_bouldin_score(X,fcm_k1)
#   print(i,'\t','Silhouette Score:' ,fcm_sil,',Calinski Harbasz Score: ',fcm_cal,',Davies Bouldin Score: ',fcm_dav)
#   l1.append(fcm_sil)
#   l2.append(fcm_cal)
#   l3.append(fcm_dav)
#   l4.append(i)

# %%
# pd.DataFrame({'Cluster_number':l4, 'Silhouette Score':l1, 'Calinski Harbasz Score':l2, 'Davies Bouldin Score':l3})

# %%
# dfc.columns

# %%
# # Let's try performing FCM Clustering on unnormalized data and check what's happening
# l1 = []
# l2 = []
# l3 = []
# l4 = []

# X = dfc.iloc[:,1:30].values

# for i in (2,3,4,5):
#   fcm = FCM(i)
#   mod_k = fcm.fit(X)
#   fcm_k2 = fcm.predict(X)
#   fcm_sil = silhouette_score(X,fcm_k2,metric='euclidean')
#   fcm_cal = calinski_harabasz_score(X,fcm_k2)
#   fcm_dav = davies_bouldin_score(X,fcm_k2)
#   print(i,'\t','Silhouette Score:' ,fcm_sil,',Calinski Harbasz Score: ',fcm_cal,',Davies Bouldin Score: ',fcm_dav)
#   l1.append(fcm_sil)
#   l2.append(fcm_cal)
#   l3.append(fcm_dav)
#   l4.append(i)

# %%
# pd.DataFrame({'Cluster_number':l4, 'Silhouette Score':l1, 'Calinski Harbasz Score':l2, 'Davies Bouldin Score':l3})

# %%
# X = df.iloc[:, 1:30].values

# fcmf = FCM(2)
# fcmf.fit(X)
# fcm_k2 = fcmf.predict(X)
# df['fcm_k2'] = fcm_k2

# %%
# df3 = pd.melt(frame=df.drop(['District', 'pred_k2', 'agg_clust2'],axis=1),id_vars='fcm_k2',var_name='parameters',value_name='values')
# df3.head()

# %%
# sns.factorplot(data = df3, y = 'values', x = 'fcm_k2', col = 'parameters', kind = 'box', sharey = False)

# %%
# df4 = pd.melt(frame=df.drop(['State', 'pred_k2', 'agg_clust2'],axis=1),id_vars='fcm_k3',var_name='parameters',value_name='values')
# df4.head()

# %%
# sns.factorplot(data = df4, y = 'values', x = 'fcm_k3', col = 'parameters', kind = 'box', sharey = False)

# %% [markdown]
# ## Map - Visualization (India - Maharashtra District)

# %%
df['Lat-Long'] = dfc['Lat-Long']
df.head()
# Out:
#      District      RAPE  OTHER IPC CRIMES  CAUSING DEATH BY NEGLIGENCE  \
# 0  AHMEDNAGAR  0.264916          0.180634                     0.380425
# 1       AKOLA  0.095943          0.158018                     0.040346
# 2    AMRAVATI  0.372315          0.246436                     0.124348
# 3  AURANGABAD  0.151313          0.170035                     0.234441
# 4        BEED  0.106921          0.083150                     0.130648
#
#    IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  DOWRY DEATHS  \
# 0                                          0.0      0.212987
# 1                                          0.0      0.168831
# 2                                          0.0      0.233766
# 3                                          0.0      1.000000
# 4                                          0.0      0.267532
#
#    HURT/GREVIOUS HURT  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 0            0.149240                             1.000000
# ...

# %%
# Checking which states fall in cluster 1 i.e, Less-Infrastructure, Better Enrollment-Ratio cluster
df[df['pred_k2']==0]
# Out:
#        District      RAPE  OTHER IPC CRIMES  CAUSING DEATH BY NEGLIGENCE  \
# 0    AHMEDNAGAR  0.264916          0.180634                     0.380425
# 1         AKOLA  0.095943          0.158018                     0.040346
# 2      AMRAVATI  0.372315          0.246436                     0.124348
# 3    AURANGABAD  0.151313          0.170035                     0.234441
# 4          BEED  0.106921          0.083150                     0.130648
# 5      BHANDARA  0.114558          0.090800                     0.044928
# 6      BULDHANA  0.135084          0.131267                     0.097302
# 7    CHANDRAPUR  0.177088          0.142254                     0.118175
# 8         DHULE  0.038186          0.077354                     0.129184
# 9    GADCHIROLI  0.070167          0.021444                     0.001973
# 10       GONDIA  0.119332          0.057133                     0.028446
# 11      HINGOLI  0.036754          0.036475                     0.007382
# ...

# %%
df.head(df.shape[0])
# Out:
#        District      RAPE  OTHER IPC CRIMES  CAUSING DEATH BY NEGLIGENCE  \
# 0    AHMEDNAGAR  0.264916          0.180634                     0.380425
# 1         AKOLA  0.095943          0.158018                     0.040346
# 2      AMRAVATI  0.372315          0.246436                     0.124348
# 3    AURANGABAD  0.151313          0.170035                     0.234441
# 4          BEED  0.106921          0.083150                     0.130648
# 5      BHANDARA  0.114558          0.090800                     0.044928
# 6      BULDHANA  0.135084          0.131267                     0.097302
# 7    CHANDRAPUR  0.177088          0.142254                     0.118175
# 8         DHULE  0.038186          0.077354                     0.129184
# 9    GADCHIROLI  0.070167          0.021444                     0.001973
# 10       GONDIA  0.119332          0.057133                     0.028446
# 11      HINGOLI  0.036754          0.036475                     0.007382
# ...

# %%
# Renaming the clusters as discussed before
df['pred_k2_label']=df.pred_k2.map({0:'Low Crime Rate', 1:'High Crime Rate'})
df.head()
# Out:
#      District      RAPE  OTHER IPC CRIMES  CAUSING DEATH BY NEGLIGENCE  \
# 0  AHMEDNAGAR  0.264916          0.180634                     0.380425
# 1       AKOLA  0.095943          0.158018                     0.040346
# 2    AMRAVATI  0.372315          0.246436                     0.124348
# 3  AURANGABAD  0.151313          0.170035                     0.234441
# 4        BEED  0.106921          0.083150                     0.130648
#
#    IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  DOWRY DEATHS  \
# 0                                          0.0      0.212987
# 1                                          0.0      0.168831
# 2                                          0.0      0.233766
# 3                                          0.0      1.000000
# 4                                          0.0      0.267532
#
#    HURT/GREVIOUS HURT  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 0            0.149240                             1.000000
# ...

# %%
# lat = 20.02
# lon = 73.69

# r_major = 6378137.000

# x = r_major * math.radians(lon)
# scale = x/lon

# y = 180.0/math.pi * math.log(math.tan(math.pi/4.0 + lat * (math.pi/180.0)/2.0)) * scale

# print(x,y)

# %%
import math
from ast import literal_eval
def merc(Coords):
    Coordinates = literal_eval(Coords)
    
    lat = Coordinates[0]
    lon = Coordinates[1]

    r_major = 6378137.000
    
    x = r_major * math.radians(lon)
    scale = x/lon
    y = 180.0/math.pi * math.log(math.tan(math.pi/4.0 + lat * (math.pi/180.0)/2.0)) * scale
    
    return (x, y)

# %%
df['coords_x'] = df['Lat-Long'].apply(lambda x: merc(x)[0])
df['coords_y'] = df['Lat-Long'].apply(lambda x: merc(x)[1])

# %%
# df_polygon = pd.read_csv('/content/drive/My Drive/Colab Notebooks Datasets/Maharashtra Multipolygon Lat-Long.csv')
# df_polygon.head()

# %%
# df_polygon['coords_x_poly'] = df_polygon['Lat-Long'].apply(lambda x: merc(x)[0])
# df_polygon['coords_y_poly'] = df_polygon['Lat-Long'].apply(lambda x: merc(x)[1])

# %%
# df_polygon.head()

# %%
# xss = list(df_polygon['coords_x_poly'])
# yss = list(df_polygon['coords_y_poly'])
# # xss = [[[xss]]]
# # yss = [[[yss]]]

# %%
def crime_color(cluster_number):
  if cluster_number == 0:
    return 'blue'
  elif cluster_number == 1:
    return 'red'

# %%
from bokeh.plotting import ColumnDataSource, figure, show, output_notebook, output_file
from bokeh.models import Text, HoverTool
from bokeh.tile_providers import CARTODBPOSITRON

# df['Grand Total'] = dfc['Grand Total']

# x_list = list(df['coords_x'])
# y_list = list(df['coords_y'])
# cluster_list = list(df['pred_k2'])
# name = list(df['District'])
# count = list(df['Grand Total'])
# label = list(df['pred_k2_label'])

# print(count)

626,21.3801936195399,21.3797514129973,21.3804704389596,21.3780729255251,21.379174744319,21.3798893555094,21.3799451080803,21.3820436508938,21.385219139052,21.3872671759394,21.3890296187219,21.3893171751475,21.3886940528883,21.3868612858197,21.3910283367883,21.3904105861796,21.39112471983,21.3908869004101,21.389413998857,21.3860867842777,21.3831969828545,21.3834031785139,21.3843490027043,21.386907927359,21.3878414218442,21.3867194708269,21.3850189265822,21.3809950845555,21.3871402177468,21.3858250986494,21.3870334367437,21.3849816047173,21.3849847739282,21.3881906708628,21.3931750949547,21.3958574542581,21.3961023576377,21.3973042385997,21.3964125194222,21.394932166986,21.3933144314159,21.388330113444,21.3875070125386,21.3891976489524,21.3905455357479,21.3906585346637,21.3938552756005,21.3916413021044,21.3748631435192,21.3737709150956,21.3724933121167,21.3675678349876,21.3658272169525,21.3629588634608,21.3565864059379,21.3528981576239,21.3504013878138,21.3568795138785,21.3619510615922,21.3676672100737,21.3703530830284,21.3716095105705,21.3578895685487,21.3364899207732,21.3193642281766,21.3050737148801,21.2952523869881,21.2892481865546,21.2867602831606,21.2855248071242,21.2791251334182]]]]


# # 8263245.801584697 2436052.2151399995
# # 8203133.276556329 2275400.352111139
# # xs = [8263245.801584697, 8203133.276556329]
# # ys = [2436052.2151399995, 2275400.352111139]



# # maha_glyph = MultiPolygons(xs="xss", ys="yss", line_width=20)
# # plot.add_glyph(maha_glyph)

# # print(type(maha_glyph))
# # print(maha_glyph)

# # p.line(xss, yss, line_width=5)

# output_notebook()
# show(p)

# %%
# from bokeh.io import curdoc, show
# from bokeh.models import ColumnDataSource, Grid, LinearAxis, MultiPolygons, Plot

# xs_dict = [
#     [ {'exterior': [1, 1, 2, 2],  'holes': [                              ]} ],
#     [ {'exterior': [1, 1, 3],     'holes': [ [1.5, 1.5, 2]                ]} ],
#     [ {'exterior': [2, 2, 4, 4],  'holes': [ [2.5, 2.5, 3], [3.5, 3, 3]   ]},
#       {'exterior': [3.5, 3.5, 4], 'holes': [                              ]} ]
# ]

# ys_dict = [
#     [ {'exterior': [4, 3, 3, 4],  'holes': [                              ]} ],
#     [ {'exterior': [1, 3, 1],     'holes': [ [1.5, 2, 1.5]                ]} ],
#     [ {'exterior': [2, 4, 4, 2],  'holes': [ [3, 3.5, 3.5], [2.5, 2.5, 3] ]},
#       {'exterior': [1, 1.5, 1.5], 'holes': [                              ]} ]
# ]

# # xs = [[[p['exterior'], *p['holes']] for p in mp] for mp in xs_dict]
# # ys = [[[p['exterior'], *p['holes']] for p in mp] for mp in ys_dict]

# xs = [[[[1,1,2,2]]]]
# ys = [[[[4,3,3,4]]]]

# print(type(xs))
# print(xs)
# print(ys)

# source = ColumnDataSource(dict(xs=xs, ys=ys))

# plot = Plot(
#     title=None, plot_width=300, plot_height=300,
#     min_border=0, toolbar_location=None)

# glyph = MultiPolygons(xs="xs", ys="ys", line_width=2)
# plot.add_glyph(source, glyph)

# print(type(glyph))
# print(glyph)

# xaxis = LinearAxis()
# plot.add_layout(xaxis, 'below')

# yaxis = LinearAxis()
# plot.add_layout(yaxis, 'left')

# plot.add_layout(Grid(dimension=0, ticker=xaxis.ticker))
# plot.add_layout(Grid(dimension=1, ticker=yaxis.ticker))

# curdoc().add_root(plot)

# show(plot)

# %%
df.columns
# Out:
# Index(['District', 'RAPE', 'OTHER IPC CRIMES', 'CAUSING DEATH BY NEGLIGENCE',
#        'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES', 'DOWRY DEATHS',
#        'HURT/GREVIOUS HURT', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
#        'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
#        'INSULT TO MODESTY OF WOMEN', 'ARSON', 'COUNTERFIETING', 'CHEATING',
#        'CRIMINAL BREACH OF TRUST', 'RIOTS', 'AUTO THEFT', 'OTHER THEFT',
#        'BURGLARY', 'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS', 'THEFT',
#        'ROBBERY', 'PREPARATION AND ASSEMBLY FOR DACOITY',
#        'KIDNAPPING & ABDUCTION', 'KIDNAPPING AND ABDUCTION OF OTHERS',
#        'DACOITY', 'CUSTODIAL RAPE', 'MURDER',
#        'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'OTHER RAPE',
#        'ATTEMPT TO MURDER', 'pred_k2', 'agg_clust2', 'Lat-Long',
#        'pred_k2_label', 'coords_x', 'coords_y'],
#       dtype='object')

# %%
df['Grand Total'] = dfc['Grand Total']
name = list(df['District'])
count = list(df['Grand Total'])
label = list(df['pred_k2_label'])

# %%
from bokeh.io import show, output_notebook, push_notebook
from bokeh.plotting import figure

from bokeh.models import CategoricalColorMapper, HoverTool, ColumnDataSource, Panel, CustomJS
from bokeh.models.widgets import CheckboxGroup, Slider, RangeSlider, Tabs, Button, Paragraph, TableColumn, DataTable, RadioGroup

from bokeh.layouts import column, row, WidgetBox, gridplot
from bokeh.palettes import Category20_16

from bokeh.application.handlers import FunctionHandler
from bokeh.application import Application

from bokeh.tile_providers import CARTODBPOSITRON

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b82bd9b3-b40a-42d5-8a7d-afe8391f5f8e">Loading BokehJS ...</span>
#     </div>

# %%
def modify_doc(doc):
    
    def make_dataset(district_list):
            
        global by_district

        by_district = pd.DataFrame(columns=['District', 'Grand_Total',
                                                 'pred_k2', 'pred_k2_label',
                                                  'coords_x', 'coords_y', 'Color',
                                           'RAPE', 'OTHER IPC CRIMES', 'CAUSING DEATH BY NEGLIGENCE',
       'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES', 'DOWRY DEATHS',
       'HURT/GREVIOUS HURT', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
       'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
       'INSULT TO MODESTY OF WOMEN', 'ARSON', 'COUNTERFIETING', 'CHEATING',
       'CRIMINAL BREACH OF TRUST', 'RIOTS', 'AUTO THEFT', 'OTHER THEFT',
       'BURGLARY', 'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS', 'THEFT',
       'ROBBERY', 'PREPARATION AND ASSEMBLY FOR DACOITY',
       'KIDNAPPING & ABDUCTION', 'KIDNAPPING AND ABDUCTION OF OTHERS',
       'DACOITY', 'CUSTODIAL RAPE', 'MURDER',
       'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'OTHER RAPE',
       'ATTEMPT TO MURDER'])


        # Iterate through all the district Names
        for i, district_name in enumerate(district_list):

            # Subset to the district
            subset = df[df['District'] == district_name]
            subset_dfc = dfc[dfc['District'] == district_name]

            index = dfc[dfc['District'] == district_name].index[0]

            arr_df = pd.DataFrame()

            arr_df['District'] = subset['District']
            arr_df['Grand_Total'] = subset['Grand Total']
            arr_df['pred_k2'] = subset['pred_k2']
            arr_df['pred_k2_label'] = subset['pred_k2_label']
            arr_df['coords_x'] = subset['coords_x']
            arr_df['coords_y'] = subset['coords_y']
            arr_df['Color'] = crime_color(subset['pred_k2'][index])            
            
            arr_df['RAPE'] = subset_dfc['RAPE']
            arr_df['OTHER IPC CRIMES'] = subset_dfc['OTHER IPC CRIMES']
            arr_df['CAUSING DEATH BY NEGLIGENCE'] = subset_dfc['CAUSING DEATH BY NEGLIGENCE']
            arr_df['IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES'] = subset_dfc['IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES']
            arr_df['DOWRY DEATHS'] = subset_dfc['DOWRY DEATHS']
            arr_df['HURT/GREVIOUS HURT'] = subset_dfc['HURT/GREVIOUS HURT']
            arr_df['CRUELTY BY HUSBAND OR HIS RELATIVES'] = subset_dfc['CRUELTY BY HUSBAND OR HIS RELATIVES']
            arr_df['ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY'] = subset_dfc['ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY']
            arr_df['INSULT TO MODESTY OF WOMEN'] = subset_dfc['INSULT TO MODESTY OF WOMEN']
            arr_df['ARSON'] = subset_dfc['ARSON']
            arr_df['COUNTERFIETING'] = subset_dfc['COUNTERFIETING']
            arr_df['CHEATING'] = subset_dfc['CHEATING']
            arr_df['CRIMINAL BREACH OF TRUST'] = subset_dfc['CRIMINAL BREACH OF TRUST']
            arr_df['RIOTS'] = subset_dfc['RIOTS']
            arr_df['AUTO THEFT'] = subset_dfc['AUTO THEFT']
            arr_df['OTHER THEFT'] = subset_dfc['OTHER THEFT']
            arr_df['ROBBERY'] = subset_dfc['ROBBERY']
            arr_df['PREPARATION AND ASSEMBLY FOR DACOITY'] = subset_dfc['PREPARATION AND ASSEMBLY FOR DACOITY']
            arr_df['KIDNAPPING & ABDUCTION'] = subset_dfc['KIDNAPPING & ABDUCTION']
            arr_df['KIDNAPPING AND ABDUCTION OF OTHERS'] = subset_dfc['KIDNAPPING AND ABDUCTION OF OTHERS']
            arr_df['DACOITY'] = subset_dfc['DACOITY']
            arr_df['CUSTODIAL RAPE'] = subset_dfc['CUSTODIAL RAPE']
            arr_df['MURDER'] = subset_dfc['MURDER']
            arr_df['CULPABLE HOMICIDE NOT AMOUNTING TO MURDER'] = subset_dfc['CULPABLE HOMICIDE NOT AMOUNTING TO MURDER']
            arr_df['OTHER RAPE'] = subset_dfc['OTHER RAPE']
            arr_df['ATTEMPT TO MURDER'] = subset_dfc['ATTEMPT TO MURDER']            
        
            by_district = by_district.append(arr_df)
            
        return ColumnDataSource(by_district)
    
    
    def make_plot(sources):

        x_list = list(by_district['coords_x'])
        y_list = list(by_district['coords_y'])
        cluster_list = list(by_district['pred_k2'])
        
        hover = HoverTool(names=['ytd_ave'],
            tooltips=[
                ("District: ", "@District"),
                ("Crime Count: ", "@Grand_Total"),
                ("Tag: ", "@pred_k2_label"),
            ]
        )

        p = figure(title="Crime Hotspots in Maharashtra", tools=['pan', 'box_zoom', 'wheel_zoom', 'save', 'reset', hover])

        p.add_tile(CARTODBPOSITRON)
        
        p.circle('coords_x', 'coords_y', size = 20, source = sources, name='ytd_ave', fill_color = 'Color')


        glyph = Text(x="coords_x", y="coords_y", text="District", text_color="#000000", text_font_size = "10px", x_offset = -10, y_offset = 25)
        p.add_glyph(sources, glyph)

        return p    
    
    
    # Update function takes three default parameters
    def update(attr, old, new):
        # Get the list of carriers for the graph
        district_to_plot = [district_selection.labels[i] for i in 
                            district_selection.active]

        # Make a new dataset based on the selected carriers and the 
        # make_dataset function defined earlier
        new_src = make_dataset(district_to_plot)

        # Update the source used the quad glpyhs
        src.data.update(new_src.data)

        
    district_selection = CheckboxGroup(labels = name, active = [0, 1])
    district_selection.on_change('active', update)

    initial_district = [district_selection.labels[i] for i in district_selection.active]
        
    src = make_dataset(initial_district)
    
    p = make_plot(src)
    

    para = Paragraph(text="""""",width = 0, height = 100)
                                
    para2 = Paragraph(text="""ABC""",width=350)
                                
    columns = [
            TableColumn(field = "District", title="District"),
            TableColumn(field = "RAPE", title="RAPE"),
            TableColumn(field = "OTHER IPC CRIMES", title="OTHER IPC CRIMES"),
            TableColumn(field = "CAUSING DEATH BY NEGLIGENCE", title="CAUSING DEATH BY NEGLIGENCE"),
            TableColumn(field = "IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES", title="IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES"),
            TableColumn(field = "DOWRY DEATHS", title="DOWRY DEATHS"),
            TableColumn(field = "HURT/GREVIOUS HURT", title="HURT/GREVIOUS HURT"),
            TableColumn(field = "CRUELTY BY HUSBAND OR HIS RELATIVES", title="CRUELTY BY HUSBAND OR HIS RELATIVES"),
            TableColumn(field = "ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY", title="ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY"),
            TableColumn(field = "INSULT TO MODESTY OF WOMEN", title="INSULT TO MODESTY OF WOMEN"),
            TableColumn(field = "ARSON", title="ARSON"),
            TableColumn(field = "COUNTERFIETING", title="COUNTERFIETING"),
            TableColumn(field = "CHEATING", title="CHEATING"),
            TableColumn(field = "CRIMINAL BREACH OF TRUST", title="CRIMINAL BREACH OF TRUST"),
            TableColumn(field = "RIOTS", title="RIOTS"),
            TableColumn(field = "AUTO THEFT", title="AUTO THEFT"),
            TableColumn(field = "OTHER THEFT", title="OTHER THEFT"),
            TableColumn(field = "ROBBERY", title="ROBBERY"),
            TableColumn(field = "PREPARATION AND ASSEMBLY FOR DACOITY", title="PREPARATION AND ASSEMBLY FOR DACOITY"),
            TableColumn(field = "KIDNAPPING & ABDUCTION", title="KIDNAPPING & ABDUCTION"),
            TableColumn(field = "KIDNAPPING AND ABDUCTION OF OTHERS", title="KIDNAPPING AND ABDUCTION OF OTHERS"),
            TableColumn(field = "DACOITY", title="DACOITY"),
            TableColumn(field = "CUSTODIAL RAPE", title="CUSTODIAL RAPE"),
            TableColumn(field = "MURDER", title="MURDER"),
            TableColumn(field = "CULPABLE HOMICIDE NOT AMOUNTING TO MURDER", title="CULPABLE HOMICIDE NOT AMOUNTING TO MURDER"),
            TableColumn(field = "OTHER RAPE", title="OTHER RAPE"),
            TableColumn(field = "ATTEMPT TO MURDER", title="ATTEMPT TO MURDER")
              ]
    
    data_table = DataTable(source = src, columns = columns, width = 1200)
    data_table = WidgetBox(data_table)
    

    
    row2 = row()     

    def my_button_handler():
#         row2.children.append(para2)
        row2.children.append(data_table)

    
    
    button = Button(label="See Statistics", button_type="success")
    button.on_click(my_button_handler)
    
    layout = column(row(district_selection, p), row(para, button), row2)
    doc.add_root(layout)    
    
    
#     layout = column(row(district_selection, p))
#     doc.add_root(layout)
    
# Set up an application
handler = FunctionHandler(modify_doc)
app = Application(handler)

# %%
# def modify_doc(doc):
    
#     def make_dataset(district_list):
            
#         global by_district

#         by_district = pd.DataFrame(columns=['District', 'Grand_Total',
#                                                  'pred_k2', 'pred_k2_label',
#                                                   'coords_x', 'coords_y', 'Color'])


#         # Iterate through all the district Names
#         for i, district_name in enumerate(district_list):

#             # Subset to the district
#             subset = df[df['District'] == district_name]

#             index = df[df['District'] == district_name].index[0]

#             arr_df = pd.DataFrame()

#             arr_df['District'] = subset['District']
#             arr_df['Grand_Total'] = subset['Grand Total']
#             arr_df['pred_k2'] = subset['pred_k2']
#             arr_df['pred_k2_label'] = subset['pred_k2_label']
#             arr_df['coords_x'] = subset['coords_x']
#             arr_df['coords_y'] = subset['coords_y']
#             arr_df['Color'] = crime_color(subset['pred_k2'][index])            
        
#             by_district = by_district.append(arr_df)
            
#         return ColumnDataSource(by_district)
    
    
#     def make_plot(sources):

#         x_list = list(by_district['coords_x'])
#         y_list = list(by_district['coords_y'])
#         cluster_list = list(by_district['pred_k2'])
        
#         hover = HoverTool(names=['ytd_ave'],
#             tooltips=[
#                 ("district: ", "@district"),
#                 ("Crime Count: ", "@Grand_Total"),
#                 ("Tag: ", "@pred_k2_label"),
#             ]
#         )

#         p = figure(title="Crime Hotspots in Maharashtra", tools=['pan', 'box_zoom', 'wheel_zoom', 'save', 'reset', hover])

#         p.add_tile(CARTODBPOSITRON)
        
#         p.circle('coords_x', 'coords_y', size = 20, source = sources, name='ytd_ave', fill_color = 'Color')


#         glyph = Text(x="coords_x", y="coords_y", text="District", text_color="#000000", text_font_size = "10px", x_offset = -10, y_offset = 25)
#         p.add_glyph(sources, glyph)

#         return p    
    
#     # Update function takes three default parameters
#     def update(attr, old, new):
#         # Get the list of carriers for the graph
#         district_to_plot = [district_selection.labels[i] for i in 
#                             district_selection.active]

#         # Make a new dataset based on the selected carriers and the 
#         # make_dataset function defined earlier
#         new_src = make_dataset(district_to_plot)

#         # Update the source used the quad glpyhs
#         src.data.update(new_src.data)

        
#     district_selection = CheckboxGroup(labels = name, active = [0, 1])
#     district_selection.on_change('active', update)

#     initial_district = [district_selection.labels[i] for i in district_selection.active]
        
#     src = make_dataset(initial_district)
    
#     p = make_plot(src)
    

#     layout = column(row(district_selection, p))
#     doc.add_root(layout)
    
# # Set up an application
# handler = FunctionHandler(modify_doc)
# app = Application(handler)

# %%
show(app)
# Out:
# <script
#     src="http://localhost:49769/autoload.js?bokeh-autoload-element=ed0a8753-40c9-460c-bfe7-712dbe567221&bokeh-absolute-url=http://localhost:49769"
#     id="ed0a8753-40c9-460c-bfe7-712dbe567221"
#     data-bokeh-model-id=""
#     data-bokeh-doc-id=""
# ></script>
# C:\Users\Vivek\AppData\Roaming\Python\Python36\site-packages\pandas\core\frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# WARNING:C:\Users\Vivek\Anaconda3\lib\site-packages\bokeh\core\validation\check.py:W-1002 (EMPTY_LAYOUT): Layout has no children: Row(id='11a015d2-f2bc-4e21-a47e-fa3d53fec038', ...)
